# %%
import pandas as pd
krx_list = pd.read_html('/Users/danielj/Downloads/krx_list.xls')
krx_list[0]
# Out:
#             회사명    종목코드                   업종  \
# 0           빅히트  352820     오디오물 출판 및 원판 녹음업
# 1           넥스틴  348210        특수 목적용 기계 제조업
# 2          원방테크   53080        일반 목적용 기계 제조업
# 3           비나텍  126340       일차전지 및 축전지 제조업
# 4     엔에이치스팩17호  359090           금융 지원 서비스업
# ...         ...     ...                  ...
# 2376     CJ대한통운     120            도로 화물 운송업
# 2377      메리츠화재      60                  보험업
# 2378         경방      50               종합 소매업
# 2379      유수홀딩스     700  회사 본부 및 경영 컨설팅 서비스업
# 2380   한진중공업홀딩스    3480    연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                            음악 기획/제작, 퍼블리싱, 아티스트 매니지먼트  2020-10-15  12월
# 1                           반도체 전공정용 패턴결함 검사장비(AEGIS 등)  2020-10-08  12월
# 2                                                클린룸 설비  2020-09-24  12월
# 3                                     초고용량 커패시터(슈퍼커패시터)  2020-09-23  12월
# 4                                             금융 지원 서비스  2020-09-23  12월
# ...                                                 ...         ...  ...
# 2376  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2377                                   손해보험(화재,해상,운송보험)  1956-07-02  12월
# 2378          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2379                                               지주사업  1956-03-03  12월
# 2380                                               지주회사  1956-03-03  12월
#
#           대표자명                          홈페이지     지역
# 0          방시혁     http://www.bighitcorp.com  서울특별시
# 1          박태훈          http://nextinsol.com    경기도
# 2          김규범        http://wonbangtech.com   충청북도
# 3          성도경         http://www.vina.co.kr   전라북도
# 4          이병훈                           NaN  서울특별시
# ...        ...                           ...    ...
# 2376       박근희    http://www.cjlogistics.com  서울특별시
# 2377       김용범     http://www.meritzfire.com  서울특별시
# 2378    김준, 김담    http://www.kyungbang.co.kr  서울특별시
# 2379       송영규  http://www.eusu-holdings.com  서울특별시
# 2380  조남호, 조원국  http://www.hhic-holdings.com    경기도
#
# [2381 rows x 9 columns]

# %%
krx_list[0].종목코드 = krx_list[0].종목코드.map('{:06d}'.format)
krx_list[0]
# Out:
#             회사명    종목코드                   업종  \
# 0           빅히트  352820     오디오물 출판 및 원판 녹음업
# 1           넥스틴  348210        특수 목적용 기계 제조업
# 2          원방테크  053080        일반 목적용 기계 제조업
# 3           비나텍  126340       일차전지 및 축전지 제조업
# 4     엔에이치스팩17호  359090           금융 지원 서비스업
# ...         ...     ...                  ...
# 2376     CJ대한통운  000120            도로 화물 운송업
# 2377      메리츠화재  000060                  보험업
# 2378         경방  000050               종합 소매업
# 2379      유수홀딩스  000700  회사 본부 및 경영 컨설팅 서비스업
# 2380   한진중공업홀딩스  003480    연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                            음악 기획/제작, 퍼블리싱, 아티스트 매니지먼트  2020-10-15  12월
# 1                           반도체 전공정용 패턴결함 검사장비(AEGIS 등)  2020-10-08  12월
# 2                                                클린룸 설비  2020-09-24  12월
# 3                                     초고용량 커패시터(슈퍼커패시터)  2020-09-23  12월
# 4                                             금융 지원 서비스  2020-09-23  12월
# ...                                                 ...         ...  ...
# 2376  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2377                                   손해보험(화재,해상,운송보험)  1956-07-02  12월
# 2378          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2379                                               지주사업  1956-03-03  12월
# 2380                                               지주회사  1956-03-03  12월
#
#           대표자명                          홈페이지     지역
# 0          방시혁     http://www.bighitcorp.com  서울특별시
# 1          박태훈          http://nextinsol.com    경기도
# 2          김규범        http://wonbangtech.com   충청북도
# 3          성도경         http://www.vina.co.kr   전라북도
# 4          이병훈                           NaN  서울특별시
# ...        ...                           ...    ...
# 2376       박근희    http://www.cjlogistics.com  서울특별시
# 2377       김용범     http://www.meritzfire.com  서울특별시
# 2378    김준, 김담    http://www.kyungbang.co.kr  서울특별시
# 2379       송영규  http://www.eusu-holdings.com  서울특별시
# 2380  조남호, 조원국  http://www.hhic-holdings.com    경기도
#
# [2381 rows x 9 columns]

# %%
df = pd.read_html('https://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13')[0]
df['종목코드'] = df['종목코드'].map('{:06d}'.format)
df = df.sort_values(by='종목코드')
df
